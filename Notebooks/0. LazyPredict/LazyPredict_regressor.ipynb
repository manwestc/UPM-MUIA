# %% [markdown]
# # Hybrid network for classification

# %%
pip install lazypredict
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lazypredict in /Users/manwest/Library/Python/3.9/lib/python/site-packages (0.2.12)
# Requirement already satisfied: click in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (1.4.0)
# Requirement already satisfied: pandas in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (2.2.0)
# Requirement already satisfied: tqdm in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (4.3.0)
# Requirement already satisfied: xgboost in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: numpy in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lightgbm->lazypredict) (1.26.3)
# Requirement already satisfied: scipy in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from lightgbm->lazypredict) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from pandas->lazypredict) (2023.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/manwest/Library/Python/3.9/lib/python/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import tensorflow as tf
import os
import numpy as np
import random
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.supervised import LazyRegressor
import numpy as np
import lazypredict

SEED = 64
os.environ['PYTHONHASHSEED']=str(SEED)
random.seed(SEED)
np.random.seed(SEED)
#from sklearn.metrics import accuracy_score, balanced_accuracy_score, roc_auc_score, f1_score
# Out:
# /Users/manwest/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
df = pd.read_csv('../../Datasets/boston.csv')
df
# Out:
#      CRIM    ZN  INDUS  CHAS  NOX   RM   AGE  DIS  RAD    TAX  PTRATIO      B  \
# 0    0.01 18.00   2.31     0 0.54 6.58 65.20 4.09    1 296.00    15.30 396.90
# 1    0.03  0.00   7.07     0 0.47 6.42 78.90 4.97    2 242.00    17.80 396.90
# 2    0.03  0.00   7.07     0 0.47 7.18 61.10 4.97    2 242.00    17.80 392.83
# 3    0.03  0.00   2.18     0 0.46 7.00 45.80 6.06    3 222.00    18.70 394.63
# 4    0.07  0.00   2.18     0 0.46 7.15 54.20 6.06    3 222.00    18.70 396.90
# ..    ...   ...    ...   ...  ...  ...   ...  ...  ...    ...      ...    ...
# 501  0.06  0.00  11.93     0 0.57 6.59 69.10 2.48    1 273.00    21.00 391.99
# 502  0.05  0.00  11.93     0 0.57 6.12 76.70 2.29    1 273.00    21.00 396.90
# 503  0.06  0.00  11.93     0 0.57 6.98 91.00 2.17    1 273.00    21.00 396.90
# 504  0.11  0.00  11.93     0 0.57 6.79 89.30 2.39    1 273.00    21.00 393.45
# 505  0.05  0.00  11.93     0 0.57 6.03 80.80 2.50    1 273.00    21.00 396.90
#
#      LSTAT  MEDV
# 0     4.98 24.00
# 1     9.14 21.60
# 2     4.03 34.70
# 3     2.94 33.40
# 4     5.33 36.20
# ..     ...   ...
# 501   9.67 22.40
# 502   9.08 20.60
# 503   5.64 23.90
# 504   6.48 22.00
# 505   7.88 11.90
#
# [506 rows x 14 columns]

# %%
X = df.iloc[:,:-1].values
y = df['MEDV'].values
y
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#        15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#        17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#        25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#        23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#        32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#        34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#        20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#        26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#        31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#        22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#        42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#        36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#        32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#        20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#        20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#        22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#        21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#        19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#        32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#        18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#        16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#        13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#         7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#        12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#        27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#         8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#         9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#        10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#        15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#        19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#        29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#        20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#        23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=SEED, shuffle=True)
X_train
# Out:
# array([[6.90500e-02, 0.00000e+00, 2.18000e+00, ..., 1.87000e+01,
#         3.96900e+02, 5.33000e+00],
#        [1.06120e-01, 3.00000e+01, 4.93000e+00, ..., 1.66000e+01,
#         3.94620e+02, 1.24000e+01],
#        [2.36862e+00, 0.00000e+00, 1.95800e+01, ..., 1.47000e+01,
#         3.91710e+02, 2.95300e+01],
#        ...,
#        [1.44760e-01, 0.00000e+00, 1.00100e+01, ..., 1.78000e+01,
#         3.91500e+02, 1.36100e+01],
#        [5.69175e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.92680e+02, 1.49800e+01],
#        [5.09017e+00, 0.00000e+00, 1.81000e+01, ..., 2.02000e+01,
#         3.85090e+02, 1.72700e+01]])

# %%
y_test
# Out:
# array([15.6, 21.5, 19.1, 34.6, 27.1, 20. , 23.2, 18.3, 17.2, 31.6, 24.5,
#        27.5, 32.7, 32.5, 28.7, 13.8, 17.2, 16. , 18.8, 19.6, 13.3, 34.9,
#        15.2, 50. , 50. , 30.1, 23.7, 21.4, 20.4, 30.5, 24.3, 24.8, 12.5,
#        19.3, 35.1, 23.1, 22.2, 20.5, 20.6, 41.7, 19.4, 24.8, 28. , 23.9,
#         9.5, 21. , 21.2, 20.5, 29.6, 13.6, 24.3, 22.2, 36.2, 36.1, 19.5,
#        34.7, 20. , 13.5, 42.3,  8.7, 18.7, 14.4, 24. , 27.5, 10.8, 29.8,
#        23.2,  7. , 25. , 10.5, 24.3, 19.8, 22.3, 13.8, 10.2, 26.2, 22.7,
#        11.8, 22.8, 23.3, 23.4, 16.2, 46. , 22. , 29.8, 16.1, 21.5, 19.6,
#        29.9, 17.1, 11.9, 50. , 17.5, 16.6, 11.3, 13.6, 43.8,  7.2, 18.5,
#        23.3, 16.1, 14.5, 15.2, 24.4, 12.7, 35.4,  7.4, 50. , 10.5, 21.1,
#        22. , 33.1, 17.6, 21.4, 28.5, 17.7, 19.4, 22.6, 50. , 19. , 27.5,
#        44.8, 20.4, 30.7, 25. , 24.5, 50. , 22.9, 18.2, 21.6, 22. , 32.2,
#        31.6, 31. , 28.7, 23.8, 22.5, 18.4, 13.4,  8.4, 20.1, 13.8, 17.5,
#        24.7, 23.7, 20.6, 36.5, 23.5, 18.2, 20.3, 19.3, 19.3, 23.1, 22.6,
#        19.8, 36. , 15.7, 31.7, 20.9, 38.7, 18.1, 20.3, 19.1, 35.2, 19.9,
#        22.4, 21.1])

# %%
#import lazypredict
lazypredict.supervised.REGRESSORS
# Out:
# [('AdaBoostRegressor', sklearn.ensemble._weight_boosting.AdaBoostRegressor),
#  ('BaggingRegressor', sklearn.ensemble._bagging.BaggingRegressor),
#  ('BayesianRidge', sklearn.linear_model._bayes.BayesianRidge),
#  ('DecisionTreeRegressor', sklearn.tree._classes.DecisionTreeRegressor),
#  ('DummyRegressor', sklearn.dummy.DummyRegressor),
#  ('ElasticNet', sklearn.linear_model._coordinate_descent.ElasticNet),
#  ('ElasticNetCV', sklearn.linear_model._coordinate_descent.ElasticNetCV),
#  ('ExtraTreeRegressor', sklearn.tree._classes.ExtraTreeRegressor),
#  ('ExtraTreesRegressor', sklearn.ensemble._forest.ExtraTreesRegressor),
#  ('GammaRegressor', sklearn.linear_model._glm.glm.GammaRegressor),
#  ('GaussianProcessRegressor',
#   sklearn.gaussian_process._gpr.GaussianProcessRegressor),
#  ('GradientBoostingRegressor', sklearn.ensemble._gb.GradientBoostingRegressor),
#  ('HistGradientBoostingRegressor',
#   sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingRegressor),
#  ('HuberRegressor', sklearn.linear_model._huber.HuberRegressor),
#  ('KNeighborsRegressor', sklearn.neighbors._regression.KNeighborsRegressor),
#  ('KernelRidge', sklearn.kernel_ridge.KernelRidge),
#  ('Lars', sklearn.linear_model._least_angle.Lars),
#  ('LarsCV', sklearn.linear_model._least_angle.LarsCV),
#  ('Lasso', sklearn.linear_model._coordinate_descent.Lasso),
#  ('LassoCV', sklearn.linear_model._coordinate_descent.LassoCV),
#  ('LassoLars', sklearn.linear_model._least_angle.LassoLars),
#  ('LassoLarsCV', sklearn.linear_model._least_angle.LassoLarsCV),
#  ('LassoLarsIC', sklearn.linear_model._least_angle.LassoLarsIC),
#  ('LinearRegression', sklearn.linear_model._base.LinearRegression),
#  ('LinearSVR', sklearn.svm._classes.LinearSVR),
#  ('MLPRegressor', sklearn.neural_network._multilayer_perceptron.MLPRegressor),
#  ('NuSVR', sklearn.svm._classes.NuSVR),
#  ('OrthogonalMatchingPursuit',
#   sklearn.linear_model._omp.OrthogonalMatchingPursuit),
#  ('OrthogonalMatchingPursuitCV',
#   sklearn.linear_model._omp.OrthogonalMatchingPursuitCV),
#  ('PassiveAggressiveRegressor',
#   sklearn.linear_model._passive_aggressive.PassiveAggressiveRegressor),
#  ('PoissonRegressor', sklearn.linear_model._glm.glm.PoissonRegressor),
#  ('QuantileRegressor', sklearn.linear_model._quantile.QuantileRegressor),
#  ('RANSACRegressor', sklearn.linear_model._ransac.RANSACRegressor),
#  ('RandomForestRegressor', sklearn.ensemble._forest.RandomForestRegressor),
#  ('Ridge', sklearn.linear_model._ridge.Ridge),
#  ('RidgeCV', sklearn.linear_model._ridge.RidgeCV),
#  ('SGDRegressor', sklearn.linear_model._stochastic_gradient.SGDRegressor),
#  ('SVR', sklearn.svm._classes.SVR),
#  ('TransformedTargetRegressor',
#   sklearn.compose._target.TransformedTargetRegressor),
#  ('TweedieRegressor', sklearn.linear_model._glm.glm.TweedieRegressor),
#  ('XGBRegressor', xgboost.sklearn.XGBRegressor),
#  ('LGBMRegressor', lightgbm.sklearn.LGBMRegressor)]

# %%
#lazypredict.supervised.REGRESSORS = lazypredict.supervised.REGRESSORS[33:36]
#lazypredict.supervised.REGRESSORS

# %%
#regressor=['RandomForestRegressor', 'XGBRegressor', 'GradientBoostingRegressor', 'HistGradientBoostingRegressor']
reg = LazyRegressor(verbose=2, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#  17%|█▋        | 7/42 [00:00<00:00, 59.26it/s]
# {'Model': 'AdaBoostRegressor', 'R-Squared': 0.8319369490435444, 'Adjusted R-Squared': 0.8176570819688129, 'RMSE': 3.7720102192041325, 'Time taken': 0.057943105697631836}
# {'Model': 'BaggingRegressor', 'R-Squared': 0.8432108971952186, 'Adjusted R-Squared': 0.8298889472837012, 'RMSE': 3.64329784147229, 'Time taken': 0.017675161361694336}
# {'Model': 'BayesianRidge', 'R-Squared': 0.7182046959684899, 'Adjusted R-Squared': 0.6942613041226753, 'RMSE': 4.884314437943621, 'Time taken': 0.007467746734619141}
# {'Model': 'DecisionTreeRegressor', 'R-Squared': 0.8063737748748365, 'Adjusted R-Squared': 0.7899218733936135, 'RMSE': 4.048730118057052, 'Time taken': 0.004619121551513672}
# {'Model': 'DummyRegressor', 'R-Squared': -0.018712516056170525, 'Adjusted R-Squared': -0.10526978866225023, 'RMSE': 9.286724458413762, 'Time taken': 0.002711057662963867}
# {'Model': 'ElasticNet', 'R-Squared': 0.6025340569603832, 'Adjusted R-Squared': 0.5687624408851217, 'RMSE': 5.800784077022441, 'Time taken': 0.0035660266876220703}
# {'Model': 'ElasticNetCV', 'R-Squared': 0.7166091173358277, 'Adjusted R-Squared': 0.6925301534493293, 'RMSE': 4.898122877909029, 'Time taken': 0.023804187774658203}
# {'Model': 'ExtraTreeRegressor', 'R-Squared': 0.6410979656600541, 'Adjusted R-Squared': 0.6106030215658103, 'RMSE': 5.512196601831752, 'Time taken': 0.003654956817626953}
# {'Model': 'ExtraTreesRegressor', 'R-Squared': 0.8813320547098081, 'Adjusted R-Squared': 0.8712491573975696, 'RMSE': 3.1695926446365514, 'Time taken': 0.06991791725158691}
# {'Model': 'GammaRegressor', 'R-Squared': 0.5852280913532428, 'Adjusted R-Squared': 0.549986033755806, 'RMSE': 5.925723821639249, 'Time taken': 0.020509958267211914}
# {'Model': 'GaussianProcessRegressor', 'R-Squared': 0.3961716768137661, 'Adjusted R-Squared': 0.34486600229467435, 'RMSE': 7.149793177329157, 'Time taken': 0.06430816650390625}
# {'Model': 'GradientBoostingRegressor', 'R-Squared': 0.8972837322109327, 'Adjusted R-Squared': 0.8885562061896395, 'RMSE': 2.9488749377269428, 'Time taken': 0.21972990036010742}
#  31%|███       | 13/42 [00:00<00:01, 14.59it/s]
# {'Model': 'HistGradientBoostingRegressor', 'R-Squared': 0.8877787137181733, 'Adjusted R-Squared': 0.8782435717465148, 'RMSE': 3.082296123982537, 'Time taken': 0.2841477394104004}
# {'Model': 'HuberRegressor', 'R-Squared': 0.6752821406425747, 'Adjusted R-Squared': 0.6476917342919439, 'RMSE': 5.243120351138712, 'Time taken': 0.006016969680786133}
# {'Model': 'KNeighborsRegressor', 'R-Squared': 0.7194345176087087, 'Adjusted R-Squared': 0.695595620412063, 'RMSE': 4.873644629642985, 'Time taken': 0.004436969757080078}
#  48%|████▊     | 20/42 [00:01<00:01, 14.55it/s]
# {'Model': 'KernelRidge', 'R-Squared': -5.2020425374745995, 'Adjusted R-Squared': -5.729013472031264, 'RMSE': 22.914168865880637, 'Time taken': 0.3901550769805908}
# {'Model': 'Lars', 'R-Squared': 0.6951504402269981, 'Adjusted R-Squared': 0.6692481900502072, 'RMSE': 5.080184968140416, 'Time taken': 0.013327836990356445}
# {'Model': 'LarsCV', 'R-Squared': 0.6684829429271417, 'Adjusted R-Squared': 0.6403148269667028, 'RMSE': 5.29772826328121, 'Time taken': 0.03365302085876465}
# {'Model': 'Lasso', 'R-Squared': 0.6416448225621436, 'Adjusted R-Squared': 0.6111963434334369, 'RMSE': 5.507995550299903, 'Time taken': 0.010301828384399414}
# {'Model': 'LassoCV', 'R-Squared': 0.720233502089394, 'Adjusted R-Squared': 0.6964624924630026, 'RMSE': 4.866700185480208, 'Time taken': 0.08098578453063965}
# {'Model': 'LassoLars', 'R-Squared': 0.6416452142306357, 'Adjusted R-Squared': 0.6111967683809512, 'RMSE': 5.507992540284928, 'Time taken': 0.008271217346191406}
# {'Model': 'LassoLarsCV', 'R-Squared': 0.7203372428217372, 'Adjusted R-Squared': 0.696575047767375, 'RMSE': 4.865797786770572, 'Time taken': 0.01711106300354004}
# {'Model': 'LassoLarsIC', 'R-Squared': 0.7208563255822515, 'Adjusted R-Squared': 0.6971382355990442, 'RMSE': 4.861279979545749, 'Time taken': 0.013881206512451172}
# {'Model': 'LinearRegression', 'R-Squared': 0.7208563255822517, 'Adjusted R-Squared': 0.6971382355990443, 'RMSE': 4.861279979545749, 'Time taken': 0.00854182243347168}
# {'Model': 'LinearSVR', 'R-Squared': 0.6615125752508457, 'Adjusted R-Squared': 0.6327522058277151, 'RMSE': 5.3531326880435115, 'Time taken': 0.011870861053466797}
#  71%|███████▏  | 30/42 [00:01<00:00, 18.71it/s]
# {'Model': 'MLPRegressor', 'R-Squared': 0.6789412085134152, 'Adjusted R-Squared': 0.6516617033544243, 'RMSE': 5.2134957316979325, 'Time taken': 0.292011022567749}
# {'Model': 'NuSVR', 'R-Squared': 0.576067061833651, 'Adjusted R-Squared': 0.5400466161070985, 'RMSE': 5.990806875736733, 'Time taken': 0.02087116241455078}
# {'Model': 'OrthogonalMatchingPursuit', 'R-Squared': 0.536256411362273, 'Adjusted R-Squared': 0.49685336134730274, 'RMSE': 6.2657880229519645, 'Time taken': 0.019886016845703125}
# {'Model': 'OrthogonalMatchingPursuitCV', 'R-Squared': 0.6623424238018636, 'Adjusted R-Squared': 0.6336525643863357, 'RMSE': 5.3465666901018345, 'Time taken': 0.013186931610107422}
# {'Model': 'PassiveAggressiveRegressor', 'R-Squared': 0.6421939524890967, 'Adjusted R-Squared': 0.6117921314587585, 'RMSE': 5.50377381029029, 'Time taken': 0.049755096435546875}
# {'Model': 'PoissonRegressor', 'R-Squared': 0.7708482199252094, 'Adjusted R-Squared': 0.7513778072391161, 'RMSE': 4.40451767008734, 'Time taken': 0.028544187545776367}
# {'Model': 'QuantileRegressor', 'R-Squared': -0.07838525793653961, 'Adjusted R-Squared': -0.17001276351284678, 'RMSE': 9.554846404854413, 'Time taken': 0.015559196472167969}
#  86%|████████▌ | 36/42 [00:02<00:00, 18.94it/s]
# {'Model': 'RANSACRegressor', 'R-Squared': 0.4545577475356086, 'Adjusted R-Squared': 0.4082129809863466, 'RMSE': 6.795339005859862, 'Time taken': 0.06264567375183105}
# {'Model': 'RandomForestRegressor', 'R-Squared': 0.8461829954563735, 'Adjusted R-Squared': 0.8331135767696602, 'RMSE': 3.6086014043959436, 'Time taken': 0.17566299438476562}
# {'Model': 'Ridge', 'R-Squared': 0.720508732418895, 'Adjusted R-Squared': 0.6967611083760561, 'RMSE': 4.864305700965259, 'Time taken': 0.003381013870239258}
# {'Model': 'RidgeCV', 'R-Squared': 0.7164030434621625, 'Adjusted R-Squared': 0.6923065700308431, 'RMSE': 4.899903442821769, 'Time taken': 0.003091096878051758}
# {'Model': 'SGDRegressor', 'R-Squared': 0.7177484640695933, 'Adjusted R-Squared': 0.6937663074219116, 'RMSE': 4.888266737362834, 'Time taken': 0.0044002532958984375}
# {'Model': 'SVR', 'R-Squared': 0.5852325084186977, 'Adjusted R-Squared': 0.549990826127476, 'RMSE': 5.925692268900108, 'Time taken': 0.006671905517578125}
# {'Model': 'TransformedTargetRegressor', 'R-Squared': 0.7208563255822517, 'Adjusted R-Squared': 0.6971382355990443, 'RMSE': 4.861279979545749, 'Time taken': 0.0034530162811279297}
# {'Model': 'TweedieRegressor', 'R-Squared': 0.5854388256348041, 'Adjusted R-Squared': 0.5502146735645588, 'RMSE': 5.924218281147114, 'Time taken': 0.005986928939819336}
#  98%|█████████▊| 41/42 [00:02<00:00, 19.64it/s]
# {'Model': 'XGBRegressor', 'R-Squared': 0.8675923621262401, 'Adjusted R-Squared': 0.8563420399539599, 'RMSE': 3.348060197807247, 'Time taken': 0.2177598476409912}
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000849 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 845
# [LightGBM] [Info] Number of data points in the train set: 339, number of used features: 13
# [LightGBM] [Info] Start training from score 22.117404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 42/42 [00:02<00:00, 15.99it/s]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# {'Model': 'LGBMRegressor', 'R-Squared': 0.8734147737170372, 'Adjusted R-Squared': 0.8626591662550862, 'RMSE': 3.2736198855522316, 'Time taken': 0.3049168586730957}

# %%
models
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.89       0.90  2.95        0.22
# HistGradientBoostingRegressor                0.88       0.89  3.08        0.28
# ExtraTreesRegressor                          0.87       0.88  3.17        0.07
# LGBMRegressor                                0.86       0.87  3.27        0.30
# XGBRegressor                                 0.86       0.87  3.35        0.22
# RandomForestRegressor                        0.83       0.85  3.61        0.18
# BaggingRegressor                             0.83       0.84  3.64        0.02
# AdaBoostRegressor                            0.82       0.83  3.77        0.06
# DecisionTreeRegressor                        0.79       0.81  4.05        0.00
# PoissonRegressor                             0.75       0.77  4.40        0.03
# TransformedTargetRegressor                   0.70       0.72  4.86        0.00
# LinearRegression                             0.70       0.72  4.86        0.01
# LassoLarsIC                                  0.70       0.72  4.86        0.01
# Ridge                                        0.70       0.72  4.86        0.00
# LassoLarsCV                                  0.70       0.72  4.87        0.02
# LassoCV                                      0.70       0.72  4.87        0.08
# KNeighborsRegressor                          0.70       0.72  4.87        0.00
# BayesianRidge                                0.69       0.72  4.88        0.01
# SGDRegressor                                 0.69       0.72  4.89        0.00
# ElasticNetCV                                 0.69       0.72  4.90        0.02
# RidgeCV                                      0.69       0.72  4.90        0.00
# Lars                                         0.67       0.70  5.08        0.01
# MLPRegressor                                 0.65       0.68  5.21        0.29
# HuberRegressor                               0.65       0.68  5.24        0.01
# LarsCV                                       0.64       0.67  5.30        0.03
# OrthogonalMatchingPursuitCV                  0.63       0.66  5.35        0.01
# LinearSVR                                    0.63       0.66  5.35        0.01
# PassiveAggressiveRegressor                   0.61       0.64  5.50        0.05
# LassoLars                                    0.61       0.64  5.51        0.01
# Lasso                                        0.61       0.64  5.51        0.01
# ExtraTreeRegressor                           0.61       0.64  5.51        0.00
# ElasticNet                                   0.57       0.60  5.80        0.00
# TweedieRegressor                             0.55       0.59  5.92        0.01
# SVR                                          0.55       0.59  5.93        0.01
# GammaRegressor                               0.55       0.59  5.93        0.02
# NuSVR                                        0.54       0.58  5.99        0.02
# OrthogonalMatchingPursuit                    0.50       0.54  6.27        0.02
# RANSACRegressor                              0.41       0.45  6.80        0.06
# GaussianProcessRegressor                     0.34       0.40  7.15        0.06
# DummyRegressor                              -0.11      -0.02  9.29        0.00
# QuantileRegressor                           -0.17      -0.08  9.55        0.02
# KernelRidge                                 -5.73      -5.20 22.91        0.39
